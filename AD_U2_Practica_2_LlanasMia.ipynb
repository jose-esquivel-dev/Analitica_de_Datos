# %% [markdown]
# <a href="https://colab.research.google.com/github/jose-esquivel-dev/Analitica_de_Datos/blob/main/AD_U2_Practica_2_LlanasMia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INSTITUTO TECNOLOGICO DE CIUDAD JUAREZ**
#
# **Ciencia y analítica de datos**
#
# MODELOS DE APRENDIZAJE
#
#
# **ACTIVIDAD 2**
# Exploración de datos
#
# ---

# %% [markdown]
# *   NOMBRE:_Mia Llanas Hernández_____
# *   NO. CONTROL:__22111513___________

# %% [markdown]
# -------

# %% [markdown]
# # CODIGO PARA ACCEDER A NUESTRO DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # IMPORTA LAS LIBRERIAS NECESARIAS

# %%
#libreria manipulacion de datos
import pandas as pd


#libreria para calculos numericos y estadisticos
import numpy as np


#Librerias para graficar
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # CONVIERTE ARCHIVO CSV A TIPO DataFrame (df)

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
credit = pd.read_csv('/content/drive/MyDrive/Análitica de Datos /credit_risk_dataset.csv')
credit
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ----

# %% [markdown]
# # **Parte 1**. Análisis descriptivo (univariante)

# %% [markdown]
# 1. Utiliza el método `info()` del dataframe, para obtener el resumen de los tipos de datos. ¿Cuántas columnas son numéricas y cuántas cualitativas?

# %% [markdown]
# <font color="orange">Las numéricas son 8 y cualitativas son 4</FONT>

# %%
#.info()muestra la informacion del dataframe numero de columnas y del tipo de dato de cada una de las columnas
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
#  2. Determina el porcentaje de valores faltantes por columna.

# %%
#.isna() revisa si existen valores nulos
#.mean() calcula promedio
credit.isna().mean()
# Out:
# person_age                    0.000000
# person_income                 0.000000
# person_home_ownership         0.000000
# person_emp_length             0.027470
# loan_intent                   0.000000
# loan_grade                    0.000000
# loan_amnt                     0.000000
# loan_int_rate                 0.095639
# loan_status                   0.000000
# loan_percent_income           0.000000
# cb_person_default_on_file     0.000000
# cb_person_cred_hist_length    0.000000
# dtype: float64

# %% [markdown]
# ----

# %% [markdown]
# # Análisis de variables numéricas

# %% [markdown]
# 3. Obtén las siguientes estadísticas descriptivas para todas las variables numéricas:
# *   Tendencia central (media, mediana)
# *   Dispersión o variabilidad (min, max, desviación estándar, cuartiles)
# *   Forma (asimetría y curtosis)
# *   Clasifica las variables `person_age` y `loan_in_rate` según los valores observados de asimetría y curtosis
#
# **NOTA**. Recuerda que muchas de estas estadísticas, puedes obtenerlas utilizando la función `describe()` y que la mediana está representada en el 2do cuartil (50%)

# %% [markdown]
# #

# %%
#AGREGUE TODAS LAS CELDAS DE CODIGO Y TEXTO QUE NECESITE

# %%
credit.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
#Tendencia central -> Media
credit.mean(numeric_only=True)
# Out:
# person_age                       27.734600
# person_income                 66074.848470
# person_emp_length                 4.789686
# loan_amnt                      9589.371106
# loan_int_rate                    11.011695
# loan_status                       0.218164
# loan_percent_income               0.170203
# cb_person_cred_hist_length        5.804211
# dtype: float64

# %%
#Tendencia central -> Mediana
credit.median(numeric_only=True)
# Out:
# person_age                       26.00
# person_income                 55000.00
# person_emp_length                 4.00
# loan_amnt                      8000.00
# loan_int_rate                    10.99
# loan_status                       0.00
# loan_percent_income               0.15
# cb_person_cred_hist_length        4.00
# dtype: float64

# %%
#Dispersión o variabilidad -> min
credit.min(numeric_only=True)
# Out:
# person_age                      20.00
# person_income                 4000.00
# person_emp_length                0.00
# loan_amnt                      500.00
# loan_int_rate                    5.42
# loan_status                      0.00
# loan_percent_income              0.00
# cb_person_cred_hist_length       2.00
# dtype: float64

# %%
#Dispersión o variabilidad -> max
credit.max(numeric_only=True)
# Out:
# person_age                        144.00
# person_income                 6000000.00
# person_emp_length                 123.00
# loan_amnt                       35000.00
# loan_int_rate                      23.22
# loan_status                         1.00
# loan_percent_income                 0.83
# cb_person_cred_hist_length         30.00
# dtype: float64

# %%
#Dispersión o variabilidad -> desviación estándar
credit.std(numeric_only=True)
# Out:
# person_age                        6.348078
# person_income                 61983.119168
# person_emp_length                 4.142630
# loan_amnt                      6322.086646
# loan_int_rate                     3.240459
# loan_status                       0.413006
# loan_percent_income               0.106782
# cb_person_cred_hist_length        4.055001
# dtype: float64

# %%
#Dispersión o variabilidad -> cuartiles
credit.quantile(numeric_only=True)
# Out:
# person_age                       26.00
# person_income                 55000.00
# person_emp_length                 4.00
# loan_amnt                      8000.00
# loan_int_rate                    10.99
# loan_status                       0.00
# loan_percent_income               0.15
# cb_person_cred_hist_length        4.00
# Name: 0.5, dtype: float64

# %%
#Forma ->asimetría
credit.skew(numeric_only=True)
# Out:
# person_age                     2.581393
# person_income                 32.865349
# person_emp_length              2.614455
# loan_amnt                      1.192477
# loan_int_rate                  0.208550
# loan_status                    1.364888
# loan_percent_income            1.064669
# cb_person_cred_hist_length     1.661790
# dtype: float64

# %%
#Asimetria y Cutosis por edad de las personas
asime_edad=round(credit.loc[:,'person_age'].skew(),2)
if asime_edad > 1:
    print('El valor de la asimetria es: ',asime_edad, ' es positiva. (cola derecha)')
elif asime_edad < -1:
    print('El valor de la asimetria es: ',asime_edad, ' es negativa. (cola izquierda)')
elif asime_edad >= -1 and asime_edad <= 1:
    print('El valor de la asimetria es: ',asime_edad, ' es alrededor de cero. (simetrica)')

kurt_edad=round(credit.loc[:,'person_age'].kurt(),2)
if kurt_edad < 0:
    print('El valor de la curtosis es: ',kurt_edad, ' es platicurtica. (Ditribucion negativa, menor a 0)')
elif kurt_edad > 0:
    print('El valor de la curtosis es: ',kurt_edad, ' es leptocurtica. (Distribucion positiva, mayor a 0)')
else:
    print('El valor de la curtosis es: ',kurt_edad, ' es mesocurtica. (Distribucion normal, alrededor de 0)')
# Out:
# El valor de la asimetria es:  2.58  es positiva. (cola derecha)
# El valor de la curtosis es:  18.56  es leptocurtica. (Distribucion positiva, mayor a 0)

# %%
#Forma -> curtosis
credit.kurt(numeric_only=True)
# Out:
# person_age                      18.560825
# person_income                 2693.272776
# person_emp_length               43.722338
# loan_amnt                        1.423565
# loan_int_rate                   -0.671609
# loan_status                     -0.137088
# loan_percent_income              1.223687
# cb_person_cred_hist_length       3.716194
# dtype: float64

# %%
#Asimetria y Curtosis por tasa de prestamo
asime_tasa=round(credit.loc[:,'loan_int_rate'].skew(),2)
if asime_tasa > 1:
    print('El valor de la asimetria es: ',asime_tasa, ' es positiva. (cola derecha)')
elif asime_tasa < -1:
    print('El valor de la asimetria es: ',asime_tasa, ' es negativa. (cola izquierda)')
else:
    print('El valor de la asimetria es: ',asime_tasa, ' es alrededor de cero. (simetrica)')

kurt_tasa=round(credit.loc[:,'loan_int_rate'].kurt(),2)
if kurt_tasa < 0:
    print('El valor de la curtosis es: ',kurt_tasa, ' es platicurtica. (Ditribucion negativa, menor a 0)')
elif kurt_tasa > 0:
    print('El valor de la curtosis es: ',kurt_tasa, ' es leptocurtica. (Distribucion positiva, mayor a 3)')
else:
    print('El valor de la curtosis es: ',kurt_tasa, ' es mesocurtica. (Distribucion normal, alrededor de 0)')
# Out:
# El valor de la asimetria es:  0.21  es alrededor de cero. (simetrica)
# El valor de la curtosis es:  -0.67  es platicurtica. (Ditribucion negativa, menor a 0)

# %%
#Variable -> person_age
credit.person_age.describe()
# Out:
# count    32581.000000
# mean        27.734600
# std          6.348078
# min         20.000000
# 25%         23.000000
# 50%         26.000000
# 75%         30.000000
# max        144.000000
# Name: person_age, dtype: float64

# %%
#Variable -> loan_in_rate
credit.loan_int_rate.describe()
# Out:
# count    29465.000000
# mean        11.011695
# std          3.240459
# min          5.420000
# 25%          7.900000
# 50%         10.990000
# 75%         13.470000
# max         23.220000
# Name: loan_int_rate, dtype: float64

# %% [markdown]
# ------

# %% [markdown]
# 4. Utiliza histogramas para determinar la distribución de los valores representados en cada variable.
# *   ¿Se corresponde con lo obtenido en el cálculo de asimetría? Como verás, los datos reales son más complejos que la teoría. Por esta razón, recuerda siempre acompañar el análisis de la asimetría con algún gráfico como un histograma.
#
# **NOTA**. Para esto también puedes ocupar los gráficos `kde` ([kernel density estimation](https://www.cienciadedatos.net/documentos/pystats02-kernel-density-estimation-kde-python.html)) que crean una curva continua y suave expandiendo la idea del histograma.

# %% [markdown]
# <font color="orange">Si ya que se nota una asimetría positiva por lo que la "cola" se alarga y se extiende hacia la derecha por lo contrario si se extiende hacia la izquierda se vera una asimetría negativa.</FONT>

# %%
#AGREGA TODAS LAS CELDAS DE CODIGO Y TEXTO QUE NECESITES

# %%
# Seleccionar solo columnas numéricas
columnas_num = credit.select_dtypes(include=['number']).columns

# Crear un histograma con KDE para cada columna numérica
for col in columnas_num:
    plt.figure(figsize=(7, 4))
    sns.histplot(credit[col], kde=True, color='pink')
    plt.title(f'Histograma y Curva KDE - {col}')
    plt.xlabel(col)
    plt.ylabel('Conteo')
    plt.show()

# %% [markdown]
# ----

# %% [markdown]
# 5. Emplea boxplots para mostrar la distribución de los datos a través de sus cuartiles.

# %%
plt.figure(figsize=(15,3))
sns.boxplot(x=credit['person_age'], color='pink')
plt.title('Edad de nacimiento')
plt.show()

# %%
plt.figure(figsize=(16,3))
sns.boxplot(x=credit['person_income'], color='pink')
plt.title('Ingreso de la persona')
plt.show()

# %%
plt.figure(figsize=(14,3))
sns.boxplot(x=credit['person_emp_length'], color='pink')
plt.title('Duración de empleo de la persona')
plt.show()

# %%
plt.figure(figsize=(14,3))
sns.boxplot(x=credit['loan_amnt'], color='pink')
plt.title('Monto de prestamo')
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.boxplot(x=credit['loan_int_rate'], color='pink')
plt.title('Tasa de interes de prestamo')
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.boxplot(x=credit['loan_status'], color='pink')
plt.title('Estado de prestamo')
plt.show()

# %%
plt.figure(figsize=(14,3))
sns.boxplot(x=credit['loan_percent_income'], color='pink')
plt.title('Porcentaje del préstamo respecto a los ingresos')
plt.show()

# %%
plt.figure(figsize=(14,3))
sns.boxplot(x=credit['cb_person_cred_hist_length'], color='pink')
plt.title('Longitud del historial de credencia de persona')
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# *   Como podrás observar hay valores atípicos en todas las variables. Ejecuta el siguiente código para identificar los valores atípicos en la variable `person_age`

# %% [markdown]
# **Interpretación Resultados**
#
# <FONT COLOR="ORANGE">Las edades estan muy altas para ser aceptadas ademas de no ser para nada realistas y otras estan ya para jubilarse</FONT>

# %%
#COMENTE CADA LINEA DE CODIGO EXPLICANDO SU USO

percentile_25 = credit["person_age"].quantile(0.25) #calcula los primeros datos con el 25%
percentile_75 = credit["person_age"].quantile(0.75) #calcula la tercera parte de los datos con el 75%

iqr = percentile_75 - percentile_25 #mide la mitad de los datos el 50% de los datos

upper_limit = percentile_75 + 1.5 * iqr #cual sea el valor encima de esto es un valor atípico
lower_limit = percentile_25 - 1.5 * iqr #cual sea el valor por debajo de esto es un valor atípico

IQR_outliers = credit[(credit["person_age"] < lower_limit) | (credit["person_age"] > upper_limit)] #filtra las edades que estan fuera de lo permitido
IQR_outliers #filtra la tabla de las edades que estan fuera de lo normal
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 81            144         250000                  RENT                4.0
# 183           144         200000              MORTGAGE                4.0
# 575           123          80004                  RENT                2.0
# 747           123          78000                  RENT                7.0
# 29121          50         900000              MORTGAGE               11.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %% [markdown]
# -----

# %% [markdown]
# # Análisis de variables de texto

# %% [markdown]
#  6. Obtén las siguientes estadísticas descriptivas para todas las variables de texto:
# *   Tendencia central (moda)
# *   Cardinalidad (cantidad de valores únicos)
# *   Recuentos únicos (número de ocurrencias para cada valor único)
#
# **NOTA**. Un resumen de estas estadísticas, puedes obtenerlas indicando en la función `describe()` que se incluirán sólo las variables de tipo object: `describe(include = 'object')`. Para los recuentos utiliza la función `df['columna'].value_counts()`

# %%
#IDENTIFIQUE CUALES SON LAS VARIABLES DE TEXTO
credit.describe(include='object')
# Out:
#        person_home_ownership loan_intent loan_grade cb_person_default_on_file
# count                  32581       32581      32581                     32581
# unique                     4           6          7                         2
# top                     RENT   EDUCATION          A                         N
# freq                   16446        6453      10777                     26836

# %%
#Tendencia central -> moda
credit.select_dtypes('object').mode()
# Out:
#   person_home_ownership loan_intent loan_grade cb_person_default_on_file
# 0                  RENT   EDUCATION          A                         N

# %%
#Cardinalidad
credit.select_dtypes('object').nunique()
# Out:
# person_home_ownership        4
# loan_intent                  6
# loan_grade                   7
# cb_person_default_on_file    2
# dtype: int64

# %%
#Recuentos unicos
credit.select_dtypes('object').value_counts()
# Out:
# person_home_ownership  loan_intent        loan_grade  cb_person_default_on_file
# RENT                   MEDICAL            B           N                            1208
#                        EDUCATION          B           N                            1069
# MORTGAGE               EDUCATION          A           N                            1047
#                        PERSONAL           A           N                             986
#                        DEBTCONSOLIDATION  A           N                             974
#                                                                                    ...
# RENT                   DEBTCONSOLIDATION  G           Y                               1
#                        HOMEIMPROVEMENT    G           N                               1
#                        EDUCATION          G           Y                               1
#                        PERSONAL           G           N                               1
# ...

# %% [markdown]
# -----

# %% [markdown]
# 7. Utiliza gráficos de barras por variable para representar la frecuencia de cada categoría.
#
# **NOTA**. seaborn posee un gráfico de recuento, para variables de tipo object, que calcula la frecuencia de cada categoría sin necesidad de utilizar la función `value_counts()`. Para generarlo debes indicar la columna: `sns.countplot(x='columna', data=df) `

# %%
sns.countplot(x='person_home_ownership', data=credit, color='pink')
plt.title('Frecuencia de casa')
# Out:
# Text(0.5, 1.0, 'Frecuencia de casa')

# %%
plt.figure(figsize=(13,4)) #Tamaño de la gráfica
sns.countplot(x='loan_intent', data=credit, color='pink')
plt.title('Frecuencia de intencion de prestamo')
# Out:
# Text(0.5, 1.0, 'Frecuencia de intencion de prestamo')

# %%
plt.figure(figsize=(5,4)) #Tamaño de la gráfica
sns.countplot(x='loan_grade', data=credit, color='pink')
plt.title('Frecuencia de calificacion de prestamo')
# Out:
# Text(0.5, 1.0, 'Frecuencia de calificacion de prestamo')

# %%
plt.figure(figsize=(4,5)) #Tamaño de la gráfica
sns.countplot(x='cb_person_default_on_file', data=credit, color='pink')
plt.title('Frecuencia de default')
# Out:
# Text(0.5, 1.0, 'Frecuencia de default')

# %% [markdown]
# -----

# %% [markdown]
# # **Parte 2**. Análisis de correlación (bivariante y multivariante)

# %% [markdown]
# La variable `loan_status` será la variable de salida (o a predecir en un modelo de ML). Analiza su relación con el resto de las variables a través de los siguientes gráficos:
#
# 8. Un box plot para visualizar la distribución de `loan_percent_income` según el `loan_status`. Interpreta el resultado.

# %%
plt.figure(figsize=(5,14)) #Tamaño de la gráfica
sns.boxplot(x=credit['loan_status'], y=credit['loan_percent_income'], color='pink')
plt.title('Porcentaje del préstamo respecto a los ingresos')
# Out:
# Text(0.5, 1.0, 'Porcentaje del préstamo respecto a los ingresos')

# %% [markdown]
# **Interpretación resultados**
#
# <FONT COLOR="ORANGE">La grafica demuestra que si existe relación pero hay una breve diferencia mayor a diferencia del otro.</FONT>

# %% [markdown]
#  9. En los gráficos de barras que obtuviste en el ejercicio 7, separa el conteo según el `load_status`, utilizando el parámetro `hue`.

# %%
sns.countplot(x='loan_intent', data=credit, hue='loan_status', color='pink')
plt.title('Frecuencia de intencion de prestamo')
# Out:
# /tmp/ipykernel_3231/82028172.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.countplot(x='loan_intent', data=credit, hue='loan_status', color='pink')
# Text(0.5, 1.0, 'Frecuencia de intencion de prestamo')

# %%
sns.countplot(x='loan_grade', data=credit, hue='loan_status', color='pink')
plt.title('Frecuencia de calificacion de prestamo')
# Out:
# /tmp/ipykernel_3231/194647113.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.countplot(x='loan_grade', data=credit, hue='loan_status', color='pink')
# Text(0.5, 1.0, 'Frecuencia de calificacion de prestamo')

# %%
sns.countplot(x='cb_person_default_on_file', data=credit, hue='loan_status', color='pink')
plt.title('Frecuencia de default')
# Out:
# /tmp/ipykernel_3231/3103600587.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.countplot(x='cb_person_default_on_file', data=credit, hue='loan_status', color='pink')
# Text(0.5, 1.0, 'Frecuencia de default')

# %%
sns.countplot(x='person_home_ownership', data=credit, hue='loan_status', color='pink')
plt.title('Frecuencia de casa')
# Out:
# /tmp/ipykernel_3231/648872915.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.countplot(x='person_home_ownership', data=credit, hue='loan_status', color='pink')
# Text(0.5, 1.0, 'Frecuencia de casa')

# %% [markdown]
# 10. Un mapa de calor con los valores de correlación de todas las variables del dataframe.
# *   ¿Qué variable tiene mayor correlación con `loan_status`?

# %% [markdown]
# **Respuesta a pregunta**
#
# <FONT COLOR="ORANGE">La variable que tiene mayor correlación con loan_status es loan_percent_income</FONT>

# %%
sns.heatmap(round(credit.corr(numeric_only=True),2),annot=True,cmap='Set2')
plt.title('Diagrama de calor')
# Out:
# Text(0.5, 1.0, 'Diagrama de calor')
